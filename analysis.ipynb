# %%
from skimage import io
normal = io.imread("normal.jpg")
snow = io.imread("snow.jpg")
sunny = io.imread("sunny.jpg")
normal[0][0]
# Out:
# array([30, 21, 24], dtype=uint8)

# %%
import matplotlib.pyplot as plt

plt.imshow(normal)
